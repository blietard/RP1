# %%
'''
folderPath = "embdFiles/"
f_file = "fake_"
endN = "_FAKE.txt"
listNouns = ['article','beard','blood','company','death','gun','id','interview','passport']
for noun in listNouns:
    fPath = folderPath + f_file + noun + endN
    arrF = np.genfromtxt(fPath,delimiter=' ',dtype='float32')
    with open('files/FAKE'+ noun+'FAKE.npy','wb') as f:
        np.save(file=f,arr=arrF)
    print("done for "+noun)
'''
# Out:
# '\nfolderPath = "embdFiles/"\nf_file = "fake_"\nendN = "_FAKE.txt"\nlistNouns = [\'article\',\'beard\',\'blood\',\'company\',\'death\',\'gun\',\'id\',\'interview\',\'passport\']\nfor noun in listNouns:\n    fPath = folderPath + f_file + noun + endN\n    arrF = np.genfromtxt(fPath,delimiter=\' \',dtype=\'float32\')\n    with open(\'files/FAKE\'+ noun+\'FAKE.npy\',\'wb\') as f:\n        np.save(file=f,arr=arrF)\n    print("done for "+noun)\n'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cols = ['fileName','noun','size','start','end']
indexer = pd.DataFrame(columns=cols)
fakes = pd.DataFrame(columns=range(1024))

# %%
listNouns = ['article','beard','blood','company','death','gun','id','interview','passport']
for noun in listNouns:
    arrF = np.load('ELMOfiles/FAKE'+noun+'FAKE.npy')
    count=len(fakes)
    fakes = fakes.append(pd.DataFrame(arrF),ignore_index=True)
    d_temp = pd.DataFrame(data=[[noun+'FAKE.npy',noun,arrF.shape[0],count,len(fakes)-1]],columns=cols)
    indexer = indexer.append(d_temp,ignore_index=True)
    
    print("done for "+noun)
# Out:
# done for article
# done for beard
# done for blood
# done for company
# done for death
# done for gun
# done for id
# done for interview
# done for passport

# %%
fakes
# Out:
#          0         1         2         3         4         5         6     \
# 0    0.026731 -0.022479  0.181596  0.063427  0.143434  0.505382  0.318516
# 1    0.422661 -0.446202  0.996371 -0.526267  0.342233  0.642562  0.631784
# 2    0.208961 -0.398749  0.913252 -0.088313  0.255677  0.625717  0.223300
# 3   -0.033709 -0.288444  0.629118  0.056776  0.715655  0.427890  1.097237
# 4    0.140274 -0.350094  0.425740 -0.101696  0.406470  0.445741  0.879036
# ..        ...       ...       ...       ...       ...       ...       ...
# 594  0.582677 -0.231728  0.249254  0.089958  0.881324  0.252513  0.205101
# 595  0.341732 -0.771228  0.748192 -0.542309  0.138273 -0.363658 -0.122650
# 596  0.348122 -0.398833  0.790428  0.054292  1.190812 -0.019278  0.994067
# 597  0.456974  0.560185  0.808718 -0.042955  0.955121  0.097916  0.999905
# 598  0.333580 -0.809560 -0.163119 -0.391483 -0.091126  0.615939  0.769919
#
#          7         8         9     ...      1014      1015      1016  \
# 0    0.207427  0.042229  0.670690  ...  0.631010  0.790113 -0.034639
# 1    0.268036 -0.136144 -0.046200  ...  0.698070  1.051745 -0.011725
# 2    0.592320  0.158232  0.564321  ...  0.263242  0.653687  0.299465
# 3    0.526606  0.442940  0.419388  ...  0.259359  0.646777  0.290017
# 4    0.811289  0.548282  0.782475  ...  0.722912  0.820634 -0.153438
# ..        ...       ...       ...  ...       ...       ...       ...
# 594  0.330714 -0.444003  0.388951  ...  0.966248  0.135230  0.714246
# 595 -0.106051  0.122122  0.344518  ...  0.607761 -0.118869  0.325967
# 596  0.404543  0.523599  0.426416  ...  0.626585 -0.156646  0.559678
# 597 -0.112274  0.231442  0.717916  ...  0.306862  0.211646 -0.510905
# 598 -0.265370  0.917656  0.904906  ...  0.473080  0.036730  0.691771
#
#          1017      1018      1019      1020      1021      1022      1023
# 0   -0.409717  0.148337  0.296040 -0.224013  0.413704 -0.033352  0.190116
# 1   -0.143240  0.190387 -0.822657 -0.864716  0.643169  0.167382 -0.374945
# 2   -0.773956  0.431308  0.032365 -0.396035  0.870504 -0.026741  0.300267
# 3   -0.782687  0.428186  0.032254 -0.395898  0.843707  0.000936  0.295757
# 4   -1.040250  0.336978  0.427941 -0.109400  0.613933 -0.102024  0.477616
# ..        ...       ...       ...       ...       ...       ...       ...
# 594 -0.273435  0.567449 -0.304936 -0.753693 -0.287817  0.267605 -0.099369
# 595 -0.952818  0.572553 -0.327006 -0.156031 -0.081134 -0.040249 -0.049351
# 596 -0.666924  0.600809 -0.194516 -0.536977 -0.329262 -0.107174  0.190685
# 597 -0.365576  0.655309  0.027319 -0.445158  0.195217 -0.823859 -0.123691
# 598 -0.728755  0.809038  0.204716 -0.377503 -0.344210  0.116607  0.771317
#
# [599 rows x 1024 columns]

# %%
priv = ['beard','blood','company','death','gun']
indexer.insert(loc=3,column='privative',value=False)
for index, row in indexer.iterrows():
    if row['noun'] in priv:
        indexer.at[index,'privative']= True

# %%
indexer
# Out:
#             fileName       noun size  privative start  end
# 0    articleFAKE.npy    article   82      False     0   81
# 1      beardFAKE.npy      beard   44       True    82  125
# 2      bloodFAKE.npy      blood  150       True   126  275
# 3    companyFAKE.npy    company   25       True   276  300
# 4      deathFAKE.npy      death   46       True   301  346
# 5        gunFAKE.npy        gun   24       True   347  370
# 6         idFAKE.npy         id   96      False   371  466
# 7  interviewFAKE.npy  interview   30      False   467  496
# 8   passportFAKE.npy   passport  102      False   497  598

# %%
priv_fakes_idx = indexer[indexer.privative]
priv_fakes_idx
# Out:
#           fileName     noun size  privative start  end
# 1    beardFAKE.npy    beard   44       True    82  125
# 2    bloodFAKE.npy    blood  150       True   126  275
# 3  companyFAKE.npy  company   25       True   276  300
# 4    deathFAKE.npy    death   46       True   301  346
# 5      gunFAKE.npy      gun   24       True   347  370

# %%
if 'priv' in fakes.columns:
    fakes = fakes.drop(columns=['priv'])
    
fakes.insert(loc=1024,column='priv',value=-1)
for index, row in priv_fakes_idx.iterrows():
    for i in range(row['start'],row['end']+1):
        fakes.at[i,'priv']= 1


if 'noun' in fakes.columns:
    fakes = fakes.drop(columns=['noun'])
    
fakes.insert(loc=1024,column='noun',value='')
for index, row in indexer.iterrows():
    for i in range(row['start'],row['end']+1):
        fakes.at[i,'noun']= row['noun']

targets = fakes['priv']
nouns = fakes['noun']
X = fakes.drop(columns=['priv','noun'])
fakes
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.026731 -0.022479  0.181596  0.063427  0.143434  0.505382  0.318516
# 1    0.422661 -0.446202  0.996371 -0.526267  0.342233  0.642562  0.631784
# 2    0.208961 -0.398749  0.913252 -0.088313  0.255677  0.625717  0.223300
# 3   -0.033709 -0.288444  0.629118  0.056776  0.715655  0.427890  1.097237
# 4    0.140274 -0.350094  0.425740 -0.101696  0.406470  0.445741  0.879036
# ..        ...       ...       ...       ...       ...       ...       ...
# 594  0.582677 -0.231728  0.249254  0.089958  0.881324  0.252513  0.205101
# 595  0.341732 -0.771228  0.748192 -0.542309  0.138273 -0.363658 -0.122650
# 596  0.348122 -0.398833  0.790428  0.054292  1.190812 -0.019278  0.994067
# 597  0.456974  0.560185  0.808718 -0.042955  0.955121  0.097916  0.999905
# 598  0.333580 -0.809560 -0.163119 -0.391483 -0.091126  0.615939  0.769919
#
#             7         8         9  ...      1016      1017      1018  \
# 0    0.207427  0.042229  0.670690  ... -0.034639 -0.409717  0.148337
# 1    0.268036 -0.136144 -0.046200  ... -0.011725 -0.143240  0.190387
# 2    0.592320  0.158232  0.564321  ...  0.299465 -0.773956  0.431308
# 3    0.526606  0.442940  0.419388  ...  0.290017 -0.782687  0.428186
# 4    0.811289  0.548282  0.782475  ... -0.153438 -1.040250  0.336978
# ..        ...       ...       ...  ...       ...       ...       ...
# 594  0.330714 -0.444003  0.388951  ...  0.714246 -0.273435  0.567449
# 595 -0.106051  0.122122  0.344518  ...  0.325967 -0.952818  0.572553
# 596  0.404543  0.523599  0.426416  ...  0.559678 -0.666924  0.600809
# 597 -0.112274  0.231442  0.717916  ... -0.510905 -0.365576  0.655309
# 598 -0.265370  0.917656  0.904906  ...  0.691771 -0.728755  0.809038
#
#          1019      1020      1021      1022      1023      noun  priv
# 0    0.296040 -0.224013  0.413704 -0.033352  0.190116   article    -1
# 1   -0.822657 -0.864716  0.643169  0.167382 -0.374945   article    -1
# 2    0.032365 -0.396035  0.870504 -0.026741  0.300267   article    -1
# 3    0.032254 -0.395898  0.843707  0.000936  0.295757   article    -1
# 4    0.427941 -0.109400  0.613933 -0.102024  0.477616   article    -1
# ..        ...       ...       ...       ...       ...       ...   ...
# 594 -0.304936 -0.753693 -0.287817  0.267605 -0.099369  passport    -1
# 595 -0.327006 -0.156031 -0.081134 -0.040249 -0.049351  passport    -1
# 596 -0.194516 -0.536977 -0.329262 -0.107174  0.190685  passport    -1
# 597  0.027319 -0.445158  0.195217 -0.823859 -0.123691  passport    -1
# 598  0.204716 -0.377503 -0.344210  0.116607  0.771317  passport    -1
#
# [599 rows x 1026 columns]

# %%
from sklearn.manifold import TSNE
import matplotlib.patches as mpatches

# %%
tsne = TSNE(n_components=2, init='pca', random_state=0)
trans_data = tsne.fit_transform(X).T

colors={'article':'blue','beard':'red','blood':'orange','company':'gold','death':'brown','gun':'darkorange','id':'green','interview':'darkblue','passport':'lime'}

plt.scatter(trans_data[0], trans_data[1], color=nouns.map(colors))
handles = [mpatches.Patch(color=colors[n],label=n) for n in ('article','beard','blood','company','death','gun','id','interview','passport')]
plt.legend(handles = handles,bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("t-SNE")
plt.axis('tight')
plt.savefig('TSNE_fakes.png',dpi=300,bbox_inches = 'tight',pad_inches = 1)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

from sklearn.preprocessing import StandardScaler as Scaler
from sklearn.decomposition import PCA


from sklearn.naive_bayes import GaussianNB as NB
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.tree import DecisionTreeClassifier as DT
from sklearn.linear_model import LogisticRegression as LR

# %%
#The training set should be balanced in term of repartition of nouns

Xtrain,Xtest,Ttrain,Ttest =train_test_split(X, targets, test_size=0.4, random_state=0, stratify=nouns,shuffle=True)

#Preview the balancing of the dataset
nouns.loc[Xtrain.index].value_counts()/len(Xtrain)
# Out:
# blood        0.250696
# passport     0.169916
# id           0.161560
# article      0.136490
# death        0.077994
# beard        0.072423
# interview    0.050139
# company      0.041783
# gun          0.038997
# Name: noun, dtype: float64

# %%
model = make_pipeline(Scaler(),KNN(3))
model.fit(Xtrain,Ttrain)
y_train = model.predict(Xtrain)
y_test = model.predict(Xtest)

Tacc = np.sum(Ttrain == y_train)/len(Xtrain)
Gacc = np.sum(Ttest == y_test)/len(Xtest)

print(Tacc,Gacc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1ae7ca40c744> in <module>
#       1 model = make_pipeline(Scaler(),KNN(3))
# ----> 2 model.fit(Xtrain,Ttrain)
#       3 y_train = model.predict(Xtrain)
#       4 y_test = model.predict(Xtest)
#       5
#
# NameError: name 'Xtrain' is not defined

# %%
def AccuracyRateBan(classifier,Xtrain,Ttrain,Xbanned,Tbanned):
    model = make_pipeline(Scaler(),PCA(n_components=0.975),classifier)
    model.fit(Xtrain,Ttrain)
    y_train = model.predict(Xtrain)
    Tacc = np.sum(Ttrain == y_train)/len(Xtrain)
    y_banned = model.predict(Xbanned)
    Bacc = np.sum(Tbanned == y_banned)/len(Xbanned)
    return (Tacc,Bacc)

def AvgAccBan(classifier):
    Taccs = np.zeros(len(listNouns))
    Baccs = np.zeros(len(listNouns))
    for i,bannedW in enumerate(listNouns):
        Xtrain = X[nouns!=bannedW]
        Ttrain = targets[nouns!=bannedW]
        Xbanned = X[nouns==bannedW]
        Tbanned = targets[nouns==bannedW]
        Tacc,Bacc = AccuracyRateBan(classifier,Xtrain,Ttrain,Xbanned,Tbanned)
        Taccs[i],Baccs[i] = Tacc, Bacc
    AvgTrain = np.mean(Taccs)
    AvgBanned = np.mean(Baccs)
    return (AvgTrain,AvgBanned)


models = {'NB':None,'KNN':range(2,41),'DT':range(3,11),'LR':None}
for modelName in models:
    if modelName == 'NB':
        classifier = NB()
        Tacc,Bacc =  AvgAccBan(classifier)
        print('NB ------ Train Accuracy : {}  ||  Test Accuracy : {}'.format(np.round(Tacc,4),np.round(Bacc,4)))
    elif modelName == 'LR':
        classifier = LR(n_jobs=4,multi_class='ovr')
        Tacc,Bacc =  AvgAccBan(classifier)
        print('LR ------ Train Accuracy : {}  ||  Test Accuracy : {}'.format(np.round(Tacc,4),np.round(Bacc,4)))
    elif modelName == 'KNN':
        params = models[modelName]
        Taccs = np.zeros(len(params))
        Baccs = np.zeros(len(params))
        for i,n in enumerate(params):
            classifier = KNN(n,n_jobs=4)
            Taccs[i],Baccs[i] =  AvgAccBan(classifier)
        best = np.argmax(Baccs)
        print('KNN({}) ------ Train Accuracy : {}  ||  Test Accuracy : {}'.format(params[best],np.round(Taccs[best],4),np.round(Baccs[best],4)))
    elif modelName == 'DT':
        params = models[modelName]
        Taccs = np.zeros(len(params))
        Baccs = np.zeros(len(params))
        for i,n in enumerate(params):
            classifier = DT(max_depth=n)
            Taccs[i],Baccs[i] =  AvgAccBan(classifier)
        best = np.argmax(Baccs)
        print('DT(max_depth:{}) ------ Train Accuracy : {}  ||  Test Accuracy : {}'.format(params[best],np.round(Taccs[best],4),np.round(Baccs[best],4)))
# Out:
# NB ------ Train Accuracy : 0.899  ||  Test Accuracy : 0.609
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-f6688b6d7913> in <module>
#      39         for i,n in enumerate(params):
#      40             classifier = KNN(n,n_jobs=4)
# ---> 41             Taccs[i],Baccs[i] =  AvgAccBan(classifier)
#      42         best = np.argmax(Baccs)
#      43         print('KNN({}) ------ Train Accuracy : {}  ||  Test Accuracy : {}'.format(params[best],np.round(Taccs[best],4),np.round(Baccs[best],4)))
#
# <ipython-input-15-f6688b6d7913> in AvgAccBan(classifier)
#      16         Xbanned = X[nouns==bannedW]
#      17         Tbanned = targets[nouns==bannedW]
# ---> 18         Tacc,Bacc = AccuracyRateBan(classifier,Xtrain,Ttrain,Xbanned,Tbanned)
#      19         Taccs[i],Baccs[i] = Tacc, Bacc
#      20     AvgTrain = np.mean(Taccs)
#
# <ipython-input-15-f6688b6d7913> in AccuracyRateBan(classifier, Xtrain, Ttrain, Xbanned, Tbanned)
#       1 def AccuracyRateBan(classifier,Xtrain,Ttrain,Xbanned,Tbanned):
#       2     model = make_pipeline(Scaler(),PCA(n_components=0.975),classifier)
# ----> 3     model.fit(Xtrain,Ttrain)
#       4     y_train = model.predict(Xtrain)
#       5     Tacc = np.sum(Ttrain == y_train)/len(Xtrain)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     348             This estimator
#     349         """
# --> 350         Xt, fit_params = self._fit(X, y, **fit_params)
#     351         with _print_elapsed_time('Pipeline',
#     352                                  self._log_message(len(self.steps) - 1)):
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     313                 message_clsname='Pipeline',
#     314                 message=self._log_message(step_idx),
# --> 315                 **fit_params_steps[name])
#     316             # Replace the transformer of the step with the fitted
#     317             # transformer. This is necessary when loading the transformer
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     726     with _print_elapsed_time(message_clsname, message):
#     727         if hasattr(transformer, 'fit_transform'):
# --> 728             res = transformer.fit_transform(X, y, **fit_params)
#     729         else:
#     730             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\decomposition\_pca.py in fit_transform(self, X, y)
#     367         C-ordered array, use 'np.ascontiguousarray'.
#     368         """
# --> 369         U, S, V = self._fit(X)
#     370         U = U[:, :self.n_components_]
#     371
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     414         # Call different fits for either full or truncated SVD
#     415         if self._fit_svd_solver == 'full':
# --> 416             return self._fit_full(X, n_components)
#     417         elif self._fit_svd_solver in ['arpack', 'randomized']:
#     418             return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\decomposition\_pca.py in _fit_full(self, X, n_components)
#     447         U, S, V = linalg.svd(X, full_matrices=False)
#     448         # flip eigenvectors' sign to enforce deterministic output
# --> 449         U, V = svd_flip(U, V)
#     450
#     451         components_ = V
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\utils\extmath.py in svd_flip(u, v, u_based_decision)
#     525     if u_based_decision:
#     526         # columns of u, rows of v
# --> 527         max_abs_cols = np.argmax(np.abs(u), axis=0)
#     528         signs = np.sign(u[max_abs_cols, range(u.shape[1])])
#     529         u *= signs
#
# KeyboardInterrupt:

# %%
nouns.value_counts()

# %%
from sklearn.feature_selection import mutual_info_classif as MIC
from sklearn.feature_selection import SelectKBest

# %%
def FS_AccuracyRateBan(k_features,classifier,Xtrain,Ttrain,Xbanned,Tbanned):
    model = make_pipeline(SelectKBest(MIC,k=k_features),Scaler(),classifier)
    model.fit(Xtrain,Ttrain)
    y_train = model.predict(Xtrain)
    Tacc = np.sum(Ttrain == y_train)/len(Xtrain)
    y_banned = model.predict(Xbanned)
    Bacc = np.sum(Tbanned == y_banned)/len(Xbanned)
    return (Tacc,Bacc)

def FS_AvgAccBan(k_features,classifier):
    Taccs = np.zeros(len(listNouns))
    Baccs = np.zeros(len(listNouns))
    for i,bannedW in enumerate(listNouns):
        Xtrain = X[nouns!=bannedW]
        Ttrain = targets[nouns!=bannedW]
        Xbanned = X[nouns==bannedW]
        Tbanned = targets[nouns==bannedW]
        Tacc,Bacc = FS_AccuracyRateBan(k_features,classifier,Xtrain,Ttrain,Xbanned,Tbanned)
        Taccs[i],Baccs[i] = Tacc, Bacc
    AvgTrain = np.mean(Taccs)
    AvgBanned = np.mean(Baccs)
    return (AvgTrain,AvgBanned)

k_range = [2,5,10,20,50,100,150,200,250,300,400,500,600]

# %%
k_best = 0
best_Bacc = 0
best_Tacc = 0
for k in k_range:
    classifier = NB()
    Tacc,Bacc =  FS_AvgAccBan(k,classifier)
    if Bacc > best_Bacc:
        k_best,best_Bacc,best_Tacc = k,Bacc,Tacc
    print('finished NB with {} features. Bacc : {}'.format(k,np.round(Bacc,4)))
print('{} features NB ------ Train Accuracy : {}  ||  Test Accuracy : {}'.format(k_best,np.round(best_Tacc,4),np.round(best_Bacc,4)))
# Out:
# finished NB with 2 features. Bacc : 0.7978
# finished NB with 5 features. Bacc : 0.7872
# finished NB with 10 features. Bacc : 0.7665
# finished NB with 20 features. Bacc : 0.7466
# finished NB with 50 features. Bacc : 0.6878
# finished NB with 100 features. Bacc : 0.6786
# finished NB with 150 features. Bacc : 0.6801
# finished NB with 200 features. Bacc : 0.6585
# finished NB with 250 features. Bacc : 0.6675
# finished NB with 300 features. Bacc : 0.661
# finished NB with 400 features. Bacc : 0.6804
# finished NB with 500 features. Bacc : 0.6698
# finished NB with 600 features. Bacc : 0.6684
# 2 features NB ------ Train Accuracy : 0.9061  ||  Test Accuracy : 0.7978

# %%
k_best = 0
best_Bacc = 0
best_Tacc = 0
for k in k_range:
    classifier = LR(n_jobs=5,multi_class='ovr')
    Tacc,Bacc =  FS_AvgAccBan(k,classifier)
    if Bacc > best_Bacc:
        k_best,best_Bacc,best_Tacc = k,Bacc,Tacc
    print('finished LR with {} features. Bacc : {}'.format(k,np.round(Bacc,4)))
print('{} features LR ------ Train Accuracy : {}  ||  Test Accuracy : {}'.format(k_best,np.round(best_Tacc,4),np.round(best_Bacc,4)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-2034924fb22c> in <module>
#       4 for k in k_range:
#       5     classifier = LR(n_jobs=5,multi_class='ovr')
# ----> 6     Tacc,Bacc =  FS_AvgAccBan(k,classifier)
#       7     if Bacc > best_Bacc:
#       8         k_best,best_Bacc,best_Tacc = k,Bacc,Tacc
#
# <ipython-input-17-3ed808a2568b> in FS_AvgAccBan(k_features, classifier)
#      16         Xbanned = X[nouns==bannedW]
#      17         Tbanned = targets[nouns==bannedW]
# ---> 18         Tacc,Bacc = FS_AccuracyRateBan(k_features,classifier,Xtrain,Ttrain,Xbanned,Tbanned)
#      19         Taccs[i],Baccs[i] = Tacc, Bacc
#      20     AvgTrain = np.mean(Taccs)
#
# <ipython-input-17-3ed808a2568b> in FS_AccuracyRateBan(k_features, classifier, Xtrain, Ttrain, Xbanned, Tbanned)
#       1 def FS_AccuracyRateBan(k_features,classifier,Xtrain,Ttrain,Xbanned,Tbanned):
#       2     model = make_pipeline(SelectKBest(MIC,k=k_features),Scaler(),classifier)
# ----> 3     model.fit(Xtrain,Ttrain)
#       4     y_train = model.predict(Xtrain)
#       5     Tacc = np.sum(Ttrain == y_train)/len(Xtrain)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     348             This estimator
#     349         """
# --> 350         Xt, fit_params = self._fit(X, y, **fit_params)
#     351         with _print_elapsed_time('Pipeline',
#     352                                  self._log_message(len(self.steps) - 1)):
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     313                 message_clsname='Pipeline',
#     314                 message=self._log_message(step_idx),
# --> 315                 **fit_params_steps[name])
#     316             # Replace the transformer of the step with the fitted
#     317             # transformer. This is necessary when loading the transformer
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     726     with _print_elapsed_time(message_clsname, message):
#     727         if hasattr(transformer, 'fit_transform'):
# --> 728             res = transformer.fit_transform(X, y, **fit_params)
#     729         else:
#     730             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
# --> 574             return self.fit(X, y, **fit_params).transform(X)
#     575
#     576
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     347
#     348         self._check_params(X, y)
# --> 349         score_func_ret = self.score_func(X, y)
#     350         if isinstance(score_func_ret, (list, tuple)):
#     351             self.scores_, self.pvalues_ = score_func_ret
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_mutual_info.py in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state)
#     449     check_classification_targets(y)
#     450     return _estimate_mi(X, y, discrete_features, True, n_neighbors,
# --> 451                         copy, random_state)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state)
#     288
#     289     mi = [_compute_mi(x, y, discrete_feature, discrete_target, n_neighbors) for
# --> 290           x, discrete_feature in zip(_iterate_columns(X), discrete_mask)]
#     291
#     292     return np.array(mi)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_mutual_info.py in <listcomp>(.0)
#     288
#     289     mi = [_compute_mi(x, y, discrete_feature, discrete_target, n_neighbors) for
# --> 290           x, discrete_feature in zip(_iterate_columns(X), discrete_mask)]
#     291
#     292     return np.array(mi)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _compute_mi(x, y, x_discrete, y_discrete, n_neighbors)
#     158         return _compute_mi_cd(y, x, n_neighbors)
#     159     elif not x_discrete and y_discrete:
# --> 160         return _compute_mi_cd(x, y, n_neighbors)
#     161     else:
#     162         return _compute_mi_cc(x, y, n_neighbors)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _compute_mi_cd(c, d, n_neighbors)
#     137     nn.set_params(algorithm='kd_tree')
#     138     nn.fit(c)
# --> 139     ind = nn.radius_neighbors(radius=radius, return_distance=False)
#     140     m_all = np.array([i.size for i in ind])
#     141
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\neighbors\_base.py in radius_neighbors(self, X, radius, return_distance, sort_results)
#     973                               sort_results=sort_results)
#     974
# --> 975                 for s in gen_even_slices(X.shape[0], n_jobs)
#     976             )
#     977             if return_distance:
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\neighbors\_base.py in _tree_query_radius_parallel_helper(tree, *args, **kwargs)
#     786     cloudpickle under PyPy.
#     787     """
# --> 788     return tree.query_radius(*args, **kwargs)
#     789
#     790
#
# KeyboardInterrupt:

# %%
k_best = 0
p_best = 0
best_Bacc = 0
best_Tacc = 0
params = models['DT']
for k in k_range:
    Taccs = np.zeros(len(params))
    Baccs = np.zeros(len(params))
    for i,n in enumerate(params):
        classifier = DT(max_depth = n)
        Taccs[i],Baccs[i] =  FS_AvgAccBan(k,classifier)
    best = np.argmax(Baccs)
    best_param = params[best]
    Tacc,Bacc = Taccs[best],Baccs[best]
    if Bacc > best_Bacc:
        k_best,p_best,best_Bacc,best_Tacc = k,best_param,Bacc,Tacc
    print('finished DT with {} features. Bacc ({}) : {}'.format(k,best_param,np.round(Bacc,4)))
print('{} features DT({}) ------ Train Accuracy : {}  ||  Test Accuracy : {}'.format(k_best,p_best,np.round(best_Tacc,4),np.round(best_Bacc,4)))
# Out:
# finished DT with 2 features. Bacc (5) : 0.7717
# finished DT with 5 features. Bacc (5) : 0.7037
# finished DT with 10 features. Bacc (4) : 0.6981
# finished DT with 20 features. Bacc (4) : 0.7393
# finished DT with 50 features. Bacc (8) : 0.7289
# finished DT with 100 features. Bacc (3) : 0.712
# finished DT with 150 features. Bacc (4) : 0.6816
# finished DT with 200 features. Bacc (7) : 0.7082
# finished DT with 250 features. Bacc (8) : 0.7071
# finished DT with 300 features. Bacc (6) : 0.6859
# finished DT with 400 features. Bacc (9) : 0.6953
# finished DT with 500 features. Bacc (5) : 0.6948
# finished DT with 600 features. Bacc (9) : 0.6818
# 2 features DT(5) ------ Train Accuracy : 0.9422  ||  Test Accuracy : 0.7717

# %%
k_best = 0
p_best = 0
best_Bacc = 0
best_Tacc = 0
params = models['KNN']
for k in k_range:
    Taccs = np.zeros(len(params))
    Baccs = np.zeros(len(params))
    for i,n in enumerate(params):
        classifier = KNN(n,n_jobs=5)
        Taccs[i],Baccs[i] =  FS_AvgAccBan(k,classifier)
    best = np.argmax(Baccs)
    best_param = params[best]
    Tacc,Bacc = Taccs[best],Baccs[best]
    if Bacc > best_Bacc:
        k_best,p_best,best_Bacc,best_Tacc = k,best_param,Bacc,Tacc
    print('finished KNN with {} features. Bacc ({}) : {}'.format(k,best_param,np.round(Bacc,4)))
print('{} features KNN({}) ------ Train Accuracy : {}  ||  Test Accuracy : {}'.format(k_best,p_best,np.round(best_Tacc,4),np.round(best_Bacc,4)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-e3f9507a00a7> in <module>
#       9     for i,n in enumerate(params):
#      10         classifier = KNN(n,n_jobs=5)
# ---> 11         Taccs[i],Baccs[i] =  FS_AvgAccBan(k,classifier)
#      12     best = np.argmax(Baccs)
#      13     best_param = params[best]
#
# <ipython-input-17-3ed808a2568b> in FS_AvgAccBan(k_features, classifier)
#      16         Xbanned = X[nouns==bannedW]
#      17         Tbanned = targets[nouns==bannedW]
# ---> 18         Tacc,Bacc = FS_AccuracyRateBan(k_features,classifier,Xtrain,Ttrain,Xbanned,Tbanned)
#      19         Taccs[i],Baccs[i] = Tacc, Bacc
#      20     AvgTrain = np.mean(Taccs)
#
# <ipython-input-17-3ed808a2568b> in FS_AccuracyRateBan(k_features, classifier, Xtrain, Ttrain, Xbanned, Tbanned)
#       1 def FS_AccuracyRateBan(k_features,classifier,Xtrain,Ttrain,Xbanned,Tbanned):
#       2     model = make_pipeline(SelectKBest(MIC,k=k_features),Scaler(),classifier)
# ----> 3     model.fit(Xtrain,Ttrain)
#       4     y_train = model.predict(Xtrain)
#       5     Tacc = np.sum(Ttrain == y_train)/len(Xtrain)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     348             This estimator
#     349         """
# --> 350         Xt, fit_params = self._fit(X, y, **fit_params)
#     351         with _print_elapsed_time('Pipeline',
#     352                                  self._log_message(len(self.steps) - 1)):
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     313                 message_clsname='Pipeline',
#     314                 message=self._log_message(step_idx),
# --> 315                 **fit_params_steps[name])
#     316             # Replace the transformer of the step with the fitted
#     317             # transformer. This is necessary when loading the transformer
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     726     with _print_elapsed_time(message_clsname, message):
#     727         if hasattr(transformer, 'fit_transform'):
# --> 728             res = transformer.fit_transform(X, y, **fit_params)
#     729         else:
#     730             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
# --> 574             return self.fit(X, y, **fit_params).transform(X)
#     575
#     576
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     347
#     348         self._check_params(X, y)
# --> 349         score_func_ret = self.score_func(X, y)
#     350         if isinstance(score_func_ret, (list, tuple)):
#     351             self.scores_, self.pvalues_ = score_func_ret
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_mutual_info.py in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state)
#     449     check_classification_targets(y)
#     450     return _estimate_mi(X, y, discrete_features, True, n_neighbors,
# --> 451                         copy, random_state)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state)
#     288
#     289     mi = [_compute_mi(x, y, discrete_feature, discrete_target, n_neighbors) for
# --> 290           x, discrete_feature in zip(_iterate_columns(X), discrete_mask)]
#     291
#     292     return np.array(mi)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_mutual_info.py in <listcomp>(.0)
#     288
#     289     mi = [_compute_mi(x, y, discrete_feature, discrete_target, n_neighbors) for
# --> 290           x, discrete_feature in zip(_iterate_columns(X), discrete_mask)]
#     291
#     292     return np.array(mi)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _compute_mi(x, y, x_discrete, y_discrete, n_neighbors)
#     158         return _compute_mi_cd(y, x, n_neighbors)
#     159     elif not x_discrete and y_discrete:
# --> 160         return _compute_mi_cd(x, y, n_neighbors)
#     161     else:
#     162         return _compute_mi_cc(x, y, n_neighbors)
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _compute_mi_cd(c, d, n_neighbors)
#     137     nn.set_params(algorithm='kd_tree')
#     138     nn.fit(c)
# --> 139     ind = nn.radius_neighbors(radius=radius, return_distance=False)
#     140     m_all = np.array([i.size for i in ind])
#     141
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\neighbors\_base.py in radius_neighbors(self, X, radius, return_distance, sort_results)
#     973                               sort_results=sort_results)
#     974
# --> 975                 for s in gen_even_slices(X.shape[0], n_jobs)
#     976             )
#     977             if return_distance:
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\envs\Study\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\envs\Study\lib\site-packages\sklearn\neighbors\_base.py in _tree_query_radius_parallel_helper(tree, *args, **kwargs)
#     786     cloudpickle under PyPy.
#     787     """
# --> 788     return tree.query_radius(*args, **kwargs)
#     789
#     790
#
# KeyboardInterrupt:

# %%
X_reduced = SelectKBest(MIC,2).fit_transform(X,targets)
X_r_sc = Scaler().fit_transform(X_reduced)
# Out:
# C:\Users\Bastien\Anaconda3\envs\RProj\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass k=2 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %%
colors_grp ={'article':'blue','beard':'red','blood':'orange','company':'gold','death':'brown','gun':'darkorange','id':'aqua','interview':'darkblue','passport':'lightblue'}
 
plt.scatter(X_r_sc.T[0],X_r_sc.T[1],color=nouns.map(colors_grp))
handles = [mpatches.Patch(color=colors_grp[n],label=n) for n in ('article','beard','blood','company','death','gun','id','interview','passport')]
plt.legend(handles = handles,bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Embeddings reduced to 2 selected dimensions")
plt.savefig("Xreduced.png",dpi=300,bbox_inches = 'tight',pad_inches = 1)
plt.show()

# %%
Taccs = np.zeros(len(listNouns))
Baccs = np.zeros(len(listNouns))
Xtr_list = []
Ttr_list = []
Xb_list = []
Tb_list  = []
for i,bannedW in enumerate(listNouns):
    Xtrain = X[nouns!=bannedW]
    Ttrain = targets[nouns!=bannedW]
    Xbanned = X[nouns==bannedW]
    Tbanned = targets[nouns==bannedW]
    Xtr_list.append(Xtrain)
    Ttr_list.append(Ttrain)
    Xb_list.append(Xbanned)
    Tb_list.append(Tbanned)
    Tacc,Bacc = FS_AccuracyRateBan(2,LR(),Xtrain,Ttrain,Xbanned,Tbanned)
    Taccs[i],Baccs[i] = Tacc, Bacc
for i,n in enumerate(nouns.unique()):
    print(n,Baccs[i].round(3)*100)
print("-------AVG------",np.mean(Baccs).round(3)*100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-2806d6d31a09> in <module>
#      14     Xb_list.append(Xbanned)
#      15     Tb_list.append(Tbanned)
# ---> 16     Tacc,Bacc = FS_AccuracyRateBan(2,LR(),Xtrain,Ttrain,Xbanned,Tbanned)
#      17     Taccs[i],Baccs[i] = Tacc, Bacc
#      18 for i,n in enumerate(nouns.unique()):
#
# <ipython-input-14-3ed808a2568b> in FS_AccuracyRateBan(k_features, classifier, Xtrain, Ttrain, Xbanned, Tbanned)
#       1 def FS_AccuracyRateBan(k_features,classifier,Xtrain,Ttrain,Xbanned,Tbanned):
#       2     model = make_pipeline(SelectKBest(MIC,k=k_features),Scaler(),classifier)
# ----> 3     model.fit(Xtrain,Ttrain)
#       4     y_train = model.predict(Xtrain)
#       5     Tacc = np.sum(Ttrain == y_train)/len(Xtrain)
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     339         """
#     340         fit_params_steps = self._check_fit_params(**fit_params)
# --> 341         Xt = self._fit(X, y, **fit_params_steps)
#     342         with _print_elapsed_time('Pipeline',
#     343                                  self._log_message(len(self.steps) - 1)):
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     305                 message_clsname='Pipeline',
#     306                 message=self._log_message(step_idx),
# --> 307                 **fit_params_steps[name])
#     308             # Replace the transformer of the step with the fitted
#     309             # transformer. This is necessary when loading the transformer
#
# ~\Anaconda3\envs\RProj\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     752     with _print_elapsed_time(message_clsname, message):
#     753         if hasattr(transformer, 'fit_transform'):
# --> 754             res = transformer.fit_transform(X, y, **fit_params)
#     755         else:
#     756             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
# --> 702             return self.fit(X, y, **fit_params).transform(X)
#     703
#     704
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     350
#     351         self._check_params(X, y)
# --> 352         score_func_ret = self.score_func(X, y)
#     353         if isinstance(score_func_ret, (list, tuple)):
#     354             self.scores_, self.pvalues_ = score_func_ret
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\feature_selection\_mutual_info.py in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state)
#     447     check_classification_targets(y)
#     448     return _estimate_mi(X, y, discrete_features, True, n_neighbors,
# --> 449                         copy, random_state)
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state)
#     284
#     285     mi = [_compute_mi(x, y, discrete_feature, discrete_target, n_neighbors) for
# --> 286           x, discrete_feature in zip(_iterate_columns(X), discrete_mask)]
#     287
#     288     return np.array(mi)
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\feature_selection\_mutual_info.py in <listcomp>(.0)
#     284
#     285     mi = [_compute_mi(x, y, discrete_feature, discrete_target, n_neighbors) for
# --> 286           x, discrete_feature in zip(_iterate_columns(X), discrete_mask)]
#     287
#     288     return np.array(mi)
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _compute_mi(x, y, x_discrete, y_discrete, n_neighbors)
#     156         return _compute_mi_cd(y, x, n_neighbors)
#     157     elif not x_discrete and y_discrete:
# --> 158         return _compute_mi_cd(x, y, n_neighbors)
#     159     else:
#     160         return _compute_mi_cc(x, y, n_neighbors)
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _compute_mi_cd(c, d, n_neighbors)
#     121             nn.set_params(n_neighbors=k)
#     122             nn.fit(c[mask])
# --> 123             r = nn.kneighbors()[0]
#     124             radius[mask] = np.nextafter(r[:, -1], 0)
#     125             k_all[mask] = k
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     723                 delayed(_tree_query_parallel_helper)(
#     724                     self._tree, X[s], n_neighbors, return_distance)
# --> 725                 for s in gen_even_slices(X.shape[0], n_jobs)
#     726             )
#     727         else:
#
# ~\Anaconda3\envs\RProj\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~\Anaconda3\envs\RProj\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\Anaconda3\envs\RProj\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\envs\RProj\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\Anaconda3\envs\RProj\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\Anaconda3\envs\RProj\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\envs\RProj\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~\Anaconda3\envs\RProj\lib\site-packages\sklearn\neighbors\_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     545     under PyPy.
#     546     """
# --> 547     return tree.query(*args, **kwargs)
#     548
#     549
#
# KeyboardInterrupt:

# %%
Taccs = np.zeros(len(listNouns))
Baccs = np.zeros(len(listNouns))
Xtr_list = []
Ttr_list = []
Xb_list = []
Tb_list  = []
for i,bannedW in enumerate(listNouns):
    Xtrain = X[nouns!=bannedW]
    Ttrain = targets[nouns!=bannedW]
    Xbanned = X[nouns==bannedW]
    Tbanned = targets[nouns==bannedW]
    Xtr_list.append(Xtrain)
    Ttr_list.append(Ttrain)
    Xb_list.append(Xbanned)
    Tb_list.append(Tbanned)
    Tacc,Bacc = FS_AccuracyRateBan(10,LR(),Xtrain,Ttrain,Xbanned,Tbanned)
    Taccs[i],Baccs[i] = Tacc, Bacc
for i,n in enumerate(nouns.unique()):
    print(n,Baccs[i].round(3)*100)
print("-------AVG------",np.mean(Baccs).round(3)*100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9b33fc96c70f> in <module>
# ----> 1 Taccs = np.zeros(len(listNouns))
#       2 Baccs = np.zeros(len(listNouns))
#       3 Xtr_list = []
#       4 Ttr_list = []
#       5 Xb_list = []
#
# NameError: name 'np' is not defined

# %%
#The training set should be balanced in term of repartition of nouns
from sklearn.svm import LinearSVC
Xtrain,Xtest,Ttrain,Ttest =train_test_split(X, targets, test_size=0.3, random_state=0, stratify=nouns,shuffle=True)
model = make_pipeline(SelectKBest(MIC,k=2),Scaler(),LinearSVC(max_iter=100000))
model.fit(Xtrain,Ttrain)
y_train = model.predict(Xtrain)
Tacc = np.sum(Ttrain == y_train)/len(Xtrain)
y_test = model.predict(Xtest)
Bacc = np.sum(Ttest == y_test)/len(Xtest)
print(Tacc,Bacc)
w = model[2].coef_[0]
i = model[2].intercept_[0]
x1 = np.linspace(-2.5,2.5,10)
a = -w[0]/w[1]
x2 = a * x1 - i/w[1]
plt.scatter(X_r_sc.T[0],X_r_sc.T[1],color=nouns.map(colors_grp))
plt.plot(x1,x2,'k--',label='LogReg Line')
handles = [mpatches.Patch(color=colors_grp[n],label=n) for n in ('article','beard','blood','company','death','gun','id','interview','passport')]
plt.legend(handles = handles,bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Separation of 2-Reduced Embeddings \n(Train 90.5 ; Test 88.3%)")
plt.savefig("Xreduced_sep.png",dpi=300,bbox_inches = 'tight',pad_inches = 1)
plt.show()
# Out:
# 0.9021479713603818 0.8833333333333333

# %%
#The training set should be balanced in term of repartition of nouns
model = make_pipeline(SelectKBest(MIC,k=10),Scaler(),LR())
model.fit(X,targets)
y = model.predict(X)
Tacc = np.sum(targets == y)/len(X)
print(Tacc)
w = model[2].coef_[0]
i = model[2].intercept_[0]
x1 = np.linspace(-1.5,2.1,10)
a = -w[0]/w[1]
x2 = a * x1 - i/w[1]
plt.scatter(X_r_sc.T[0],X_r_sc.T[1],color=nouns.map(colors))
plt.plot(x1,x2,'k--',label='LogReg Line')
handles = [mpatches.Patch(color=colors[n],label=n) for n in ('article','beard','blood','company','death','gun','id','interview','passport')]
plt.legend(handles = handles,bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Separation of Reduced Embeddings (95.0%)")
plt.savefig("FullXreduced_sep.png",dpi=120,bbox_inches = 'tight',pad_inches = 1)
plt.show()
# Out:
# 0.9565943238731218

# %%
selector = SelectKBest(MIC,2)
X_reduced = selector.fit_transform(X,targets)
selected = selector.get_support()
np.where(selected)
# Out:
# C:\Users\Bastien\Anaconda3\envs\RProj\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass k=2 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# (array([531, 816], dtype=int64),)
